# %%
import pandas as pd

# %%
#criando uma series
s = pd.Series(list('asdesdsasdeedseads'))

# %%
s
# Out:
# 0     a
# 1     s
# 2     d
# 3     e
# 4     s
# 5     d
# 6     s
# 7     a
# 8     s
# 9     d
# 10    e
# 11    e
# 12    d
# 13    s
# 14    e
# 15    a
# 16    d
# 17    s
# dtype: object

# %%
#mostrando apenas os valores unicos, sem repetição
s.unique()
# Out:
# array(['a', 's', 'd', 'e'], dtype=object)

# %%
#monstrando a frequencia de cada elemento
s.value_counts()
# Out:
# s    6
# d    5
# e    4
# a    3
# dtype: int64

# %%
dados = pd.read_csv('dados/aluguel.csv',sep=';')

# %%
#retorna quais são os tipos
dados.Tipo.unique()
# Out:
# array(['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila',
#        'Quitinete'], dtype=object)

# %%
#retorna a quantidade de cada tipo
dados.Tipo.value_counts()
# Out:
# Apartamento           16923
# Casa de Condomínio      964
# Casa                    898
# Quitinete               813
# Casa de Vila            233
# Name: Tipo, dtype: int64

# %% [markdown]
# # Testando Moedas

# %%
#Temos 5 moedas que foram jogadas 50 vezes
#Onde "c" é cara e "C" é Coroa
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)

# %%
moedas
# Out:
#    m1 m2 m3 m4 m5
# 0   C  C  C  c  C
# 1   C  C  c  C  C
# 2   c  C  c  C  C
# 3   C  C  C  c  c
# 4   C  C  C  c  C
# 5   c  c  c  C  c
# 6   c  c  c  C  C
# 7   C  C  C  c  c
# 8   C  c  c  c  C
# 9   C  c  C  C  c
# 10  c  C  C  C  C
# 11  c  c  C  c  C
# 12  C  C  C  c  C
# 13  c  C  C  C  c
# 14  C  C  C  C  C
# 15  c  C  C  c  C
# 16  c  c  C  c  c
# 17  C  c  C  c  C
# 18  c  C  C  c  c
# 19  C  c  c  C  C
# 20  c  c  c  c  C
# 21  C  c  c  C  c
# 22  C  c  C  c  c
# 23  C  C  c  C  C
# 24  c  c  c  c  c
# 25  C  c  C  C  C
# 26  C  C  C  c  C
# 27  c  c  C  C  c
# 28  c  c  C  c  c
# 29  c  C  C  C  c
# 30  C  C  C  c  C
# 31  C  c  c  C  c
# 32  c  C  c  C  c
# 33  C  c  C  C  C
# 34  c  c  C  C  C
# 35  C  C  C  c  c
# 36  c  c  c  c  C
# 37  C  C  c  c  c
# 38  c  c  c  c  C
# 39  c  C  C  C  c
# 40  c  C  C  C  C
# 41  C  c  C  C  c
# 42  C  C  c  c  C
# 43  c  c  C  C  c
# 44  C  c  C  C  c
# 45  c  C  c  c  c
# 46  c  c  c  C  c
# 47  c  c  c  C  c
# 48  C  C  C  C  C
# ...

# %%
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])

# %%
df
# Out:
#    Faces
# c   Cara
# C  Coroa

# %%
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1,sort=True)

# %%
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# C  Coroa  25  24  31  27  25
# c   Cara  25  26  19  23  25
